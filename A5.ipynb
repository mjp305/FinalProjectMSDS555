# %%
# !pip install pyspark
# Out:
# ...
#      ---------------------------------------- 0.0/434.1 MB ? eta -:--:--
#      ---------------------------------------- 0.3/434.1 MB ? eta -:--:--
#      ---------------------------------------- 0.8/434.1 MB 2.1 MB/s eta 0:03:25
#      ---------------------------------------- 1.8/434.1 MB 2.9 MB/s eta 0:02:28
#      ---------------------------------------- 4.7/434.1 MB 5.8 MB/s eta 0:01:15
#       --------------------------------------- 6.6/434.1 MB 6.5 MB/s eta 0:01:07
#       --------------------------------------- 9.7/434.1 MB 7.9 MB/s eta 0:00:54
#      - ------------------------------------- 12.8/434.1 MB 9.0 MB/s eta 0:00:48
#      - ------------------------------------- 16.3/434.1 MB 9.9 MB/s eta 0:00:43
#      - ------------------------------------ 18.4/434.1 MB 10.0 MB/s eta 0:00:42
#      - ------------------------------------ 21.2/434.1 MB 10.3 MB/s eta 0:00:41
#      -- ----------------------------------- 24.4/434.1 MB 10.7 MB/s eta 0:00:39
# ...

# %%
from pyspark.sql import SparkSession# Initialize SparkSessionspark = SparkSession.builder.appName("AdultDataLoad").getOrCreate()# Load the datadf = spark.read.csv("adult.csv", header=True, inferSchema=True)# Show top 5 rows and schemadf.show(5)df.printSchema()
